# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from clevr_data import CLEVR
from torchvision import transforms as T

# %%
transform = []
transform.append(T.Resize((128, 128)))
transform.append(T.ToTensor())
transform.append(T.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)))
transform = T.Compose(transform)

# %%
dataset = CLEVR(dataroot='/media/namrata/Data/data/CLEVR_v1.0/images', 
					annotations='/media/namrata/Data/data/CLEVR_train_data_full.json', 
					mode='train', transform=transform)

# %%
len(dataset)
# Out:
# 70000

# %%
for i in range(10):
    idx = np.random.randint(len(dataset))
    image, src_attr, trg_attr, cmd_tensor, txt_lens, cmd = dataset[i]
#     if trg_attr.shape[0] > 1:
#         import pdb; pdb.set_trace()
    image = (image.permute(1, 2, 0).numpy() * 0.5) + 0.5
    plt.imshow(image)
    plt.title(cmd)
    plt.show()
